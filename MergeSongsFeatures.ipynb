# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("ExtractedSongInformation\\SongFeatures.csv")
df2 = pd.read_csv("ExtractedSongInformation\\SongInfoWithID.csv")

# %%
df1.head()
# Out:
#    Index                  SongID  Danceability  Energy  Key  Loudness  Mode  \
# 0      0  39QJ7KkN3L8LLqQqsO85W1         0.896   0.678    0    -2.546     0
# 1      1  0Aqi7ArnBrGblW5T6p2jmD         0.785   0.431   10    -8.756     0
# 2      2  1smFN2CLqGROu0J0UyvDfL         0.483   0.468    8    -7.642     1
# 3      3  25MPTnqXQB1H6OkwSYUXWx         0.384   0.728    7    -6.503     0
# 4      4  0gzu5mm36VJH2Zqu8sQPTf         0.955   0.538    1    -8.394     1
#
#    Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 0       0.0815        0.0137          0.000041    0.1100    0.604  130.024
# 1       0.0364        0.1230          0.000000    0.0887    0.236  127.085
# 2       0.0341        0.7850          0.000000    0.1520    0.319  135.864
# 3       0.0623        0.3290          0.000018    0.3290    0.311  156.396
# 4       0.0734        0.1320          0.001460    0.0704    0.837  116.977
#
#    Duration_ms
# 0       205450
# 1       159382
# ...

# %%
df2.head()
# Out:
#                                             SongName           EndTime  \
# 0                                         Saiyaan Ji  2021-02-02 02:08
# 1                                            Falling  2021-02-02 02:09
# 2                                             Shayad  2021-02-02 02:09
# 3  Malang (Title Track) [From "Malang - Unleash T...  2021-02-02 02:14
# 4                      Genda Phool (feat. Payal Dev)  2021-02-02 02:14
#
#           ArtistName  msPlayed                  SongID  Popularity
# 0  Yo Yo Honey Singh     64760  39QJ7KkN3L8LLqQqsO85W1          62
# 1      Trevor Daniel     23970  0Aqi7ArnBrGblW5T6p2jmD          84
# 2             Pritam      6210  1smFN2CLqGROu0J0UyvDfL          72
# 3         Ved Sharma    287374  25MPTnqXQB1H6OkwSYUXWx          68
# 4            Badshah     27705  0gzu5mm36VJH2Zqu8sQPTf          67

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (3731, 14)
# (3731, 6)

# %%
df = df2.copy(deep=True)
df.drop(["SongID"], axis=1, inplace=True)

# %%
pd.concat([df1, df], axis=1, join="inner")
# Out:
#       Index                  SongID  Danceability  Energy  Key  Loudness  \
# 0         0  39QJ7KkN3L8LLqQqsO85W1         0.896   0.678    0    -2.546
# 1         1  0Aqi7ArnBrGblW5T6p2jmD         0.785   0.431   10    -8.756
# 2         2  1smFN2CLqGROu0J0UyvDfL         0.483   0.468    8    -7.642
# 3         3  25MPTnqXQB1H6OkwSYUXWx         0.384   0.728    7    -6.503
# 4         4  0gzu5mm36VJH2Zqu8sQPTf         0.955   0.538    1    -8.394
# ...     ...                     ...           ...     ...  ...       ...
# 3726   3726  18XlJEroUwFo0tLZxscgXE         0.766   0.706    7    -6.553
# 3727   3727  0fsEFwLSJTSHSawhe864Cp         0.735   0.784   11    -7.128
# 3728   3728  5I2UElY0XPnPhQhBTxBcq3         0.701   0.463    6    -7.212
# 3729   3729  0o2lMW2T77pq8utWLQ4b2U         0.595   0.628    1    -9.449
# 3730   3730  5TuICc3rZeDaNP7mpRqlFj         0.544   0.152    4   -17.995
#
#       Mode  Speechiness  Acousticness  Instrumentalness  Liveness  Valence  \
# ...

# %%
df = pd.concat([df1, df], axis=1, join="inner")
df.columns
# Out:
# Index(['Index', 'SongID', 'Danceability', 'Energy', 'Key', 'Loudness', 'Mode',
#        'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo', 'Duration_ms', 'SongName', 'EndTime', 'ArtistName',
#        'msPlayed', 'Popularity'],
#       dtype='object')

# %%
cols = ["Index", "EndTime", "SongName", "ArtistName", "msPlayed", "Popularity", 'SongID', 'Danceability', 'Energy', 'Key', 'Loudness', 'Mode',
       'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
       'Valence', 'Tempo', 'Duration_ms']
df.reindex(columns=cols)
# Out:
#       Index           EndTime  \
# 0         0  2021-02-02 02:08
# 1         1  2021-02-02 02:09
# 2         2  2021-02-02 02:09
# 3         3  2021-02-02 02:14
# 4         4  2021-02-02 02:14
# ...     ...               ...
# 3726   3726  2021-09-17 09:17
# 3727   3727  2021-09-17 09:20
# 3728   3728  2021-09-17 09:25
# 3729   3729  2021-09-17 09:28
# 3730   3730  2021-09-17 09:34
#
#                                                SongName         ArtistName  \
# 0                                            Saiyaan Ji  Yo Yo Honey Singh
# 1                                               Falling      Trevor Daniel
# 2                                                Shayad             Pritam
# 3     Malang (Title Track) [From "Malang - Unleash T...         Ved Sharma
# 4                         Genda Phool (feat. Payal Dev)            Badshah
# ...                                                 ...                ...
# ...

# %%
df = df.reindex(columns=cols)

# %%
df
# Out:
#       Index           EndTime  \
# 0         0  2021-02-02 02:08
# 1         1  2021-02-02 02:09
# 2         2  2021-02-02 02:09
# 3         3  2021-02-02 02:14
# 4         4  2021-02-02 02:14
# ...     ...               ...
# 3726   3726  2021-09-17 09:17
# 3727   3727  2021-09-17 09:20
# 3728   3728  2021-09-17 09:25
# 3729   3729  2021-09-17 09:28
# 3730   3730  2021-09-17 09:34
#
#                                                SongName         ArtistName  \
# 0                                            Saiyaan Ji  Yo Yo Honey Singh
# 1                                               Falling      Trevor Daniel
# 2                                                Shayad             Pritam
# 3     Malang (Title Track) [From "Malang - Unleash T...         Ved Sharma
# 4                         Genda Phool (feat. Payal Dev)            Badshah
# ...                                                 ...                ...
# ...

# %%
df.to_csv("ExtractedSongInformation\\SpotifySongs.csv", index=None)
